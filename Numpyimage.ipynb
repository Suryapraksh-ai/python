# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
#get the image to display
hourse_img = Image.open(r'E:\horse\horse.jpg')

# %%
hourse_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=526x664>

# %%
# cover that image into array as backend to store
arr_img = np.array(hourse_img)
print(arr_img)
print(type(arr_img))
print("the dimensions of image is:",arr_img.shape)
# Out:
# [[[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  [[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  [[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  ...
#
#  [[ 66  81  42]
#   [ 55  70  31]
#   [ 55  70  31]
#   ...
#   [ 60  81  42]
#   [ 63  84  45]
#   [ 60  81  42]]
#
#  [[ 26  41   2]
#   [ 36  51  12]
#   [ 60  75  36]
#   ...
#   [ 65  86  47]
#   [ 63  84  45]
#   [ 54  75  36]]
#
#  [[ 51  66  27]
#   [ 48  63  24]
#   [ 49  64  25]
#   ...
#   [ 74  95  56]
#   [ 64  85  46]
#   [ 45  66  27]]]
# <class 'numpy.ndarray'>
# the dimensions of image is: (664, 526, 3)

# %%
# display image ino the axis
plt.imshow(arr_img)

# %%
first_cl = arr_img.copy()
print(first_cl)
# Out:
# [[[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  [[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  [[ 25  61  77]
#   [ 25  61  77]
#   [ 25  61  77]
#   ...
#   [101 138 147]
#   [101 138 147]
#   [101 138 147]]
#
#  ...
#
#  [[ 66  81  42]
#   [ 55  70  31]
#   [ 55  70  31]
#   ...
#   [ 60  81  42]
#   [ 63  84  45]
#   [ 60  81  42]]
#
#  [[ 26  41   2]
#   [ 36  51  12]
#   [ 60  75  36]
#   ...
#   [ 65  86  47]
#   [ 63  84  45]
#   [ 54  75  36]]
#
#  [[ 51  66  27]
#   [ 48  63  24]
#   [ 49  64  25]
#   ...
#   [ 74  95  56]
#   [ 64  85  46]
#   [ 45  66  27]]]

# %%
plt.imshow(first_cl)

# %%
plt.imshow(first_cl[:,:,0])

# %%
plt.imshow(first_cl[:,:,2], cmap ="gray")

# %%
plt.imshow(first_cl[:,:,0],cmap="Purples")
