# %%
import pandas as pd

# %%
movie = pd.read_csv(r'C:\Users\ICON\Downloads\Movie-Rating.csv')

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(movie.columns)
# Out:
# 6

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
len(movie)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings','Budget', 'Year']

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRatings      Budget         Year
# count    559.000000       559.000000  559.000000   559.000000
# mean      47.309481        58.744186   50.236136  2009.152057
# std       26.413091        16.826887   48.731817     1.362632
# min        0.000000         0.000000    0.000000  2007.000000
# 25%       25.000000        47.000000   20.000000  2008.000000
# 50%       46.000000        58.000000   35.000000  2009.000000
# 75%       70.000000        72.000000   65.000000  2010.000000
# max       97.000000        96.000000  300.000000  2011.000000

# %%
movie.Film = movie.Film.astype('category')

# %%
movie.Year = movie.Year.astype('category')

# %%
movie.Genre = movie.Genre.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings')
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='hex')
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='reg')

# %%
#histogram

# %%
m1 = sns.distplot(movie.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movie.AudienceRatings,bins=15)

# %%
sns.set_style('white') #normal distribution called as bell curved

# %%
n1 = plt.hist(movie.AudienceRatings,bins=20) #uniforma distribution

# %%
plt.hist(movie.Budget)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'Budget', 'Year'], dtype='object')

# %%
plt.hist(movie[movie.Genre=='Drama'].Budget)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  Budget  \
# 0  (500) Days of Summer      Comedy            87               81       8
# 1            10,000 B.C.  Adventure             9               44     105
# 2             12 Rounds      Action            30               52      20
# 3              127 Hours  Adventure            93               84      18
# 4              17 Again      Comedy            55               70      20
#
#    Year
# 0  2009
# 1  2008
# 2  2009
# 3  2010
# 4  2009

# %%
movie.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
#below plots are stacked histogram beacuse of overlap

# %%
plt.hist(movie[movie.Genre == 'Action'].Budget)
# Out:
# (array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movie[movie.Genre == 'Thriller'].Budget,bins=20)
# Out:
# (array([2., 9., 3., 6., 1., 1., 3., 2., 1., 1., 3., 1., 0., 1., 0., 0., 1.,
#         0., 0., 1.]),
#  array([  4.  ,  13.05,  22.1 ,  31.15,  40.2 ,  49.25,  58.3 ,  67.35,
#          76.4 ,  85.45,  94.5 , 103.55, 112.6 , 121.65, 130.7 , 139.75,
#         148.8 , 157.85, 166.9 , 175.95, 185.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(movie[movie.Genre=='Drama'].Budget, bins=20)
# Out:
# (array([14., 11., 27., 13., 13.,  5.,  5.,  3.,  4.,  2.,  2.,  0.,  0.,
#          1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  0. ,   7.5,  15. ,  22.5,  30. ,  37.5,  45. ,  52.5,  60. ,
#          67.5,  75. ,  82.5,  90. ,  97.5, 105. , 112.5, 120. , 127.5,
#         135. , 142.5, 150. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist([movie[movie.Genre == 'Action'].Budget,\
         movie[movie.Genre == 'Drama'].Budget,\
         movie[movie.Genre == 'Thriller'].Budget,\
         movie[movie.Genre == 'Comedy'].Budget],
        bins=20, stacked=True)
# Out:
# (array([[  7.,  22.,  27.,  16.,   8.,  16.,   9.,   5.,   7.,   6.,  12.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 32.,  62.,  45.,  24.,  14.,  18.,  10.,   5.,   7.,   6.,  13.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 34.,  73.,  52.,  26.,  18.,  20.,  14.,   6.,   8.,   6.,  14.,
#            2.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 64., 127.,  88.,  44.,  32.,  34.,  18.,   7.,   8.,   6.,  14.,
#            3.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.]]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#         165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]),
#  <a list of 4 BarContainer objects>)

# %%
# if you have 100 categories you cannot copy & paste all the things
for gen in movie.Genre.cat.categories:
      print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1= sns.lmplot( data= movie, x='CriticRating',y='AudienceRatings',fit_reg=False)

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating',y='AudienceRatings',\
                 fit_reg = False, hue='Genre')

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'Budget', 'Year'], dtype='object')

# %%
plt.style.use('dark_background')
vis1= sns.lmplot(data=movie, x='CriticRating', y='AudienceRatings', fit_reg=False, hue='Genre',height=10,aspect=1)

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
plt.style.use('default')
k1 = sns.kdeplot(x='CriticRating', y ='AudienceRatings',data=movie)

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1= sns.kdeplot(data=movie, x='CriticRating',y='AudienceRatings', shade=True,shade_lowest=False,cmap='Reds')

# %%
k1= sns.kdeplot(data=movie, x='CriticRating',y='AudienceRatings',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')

# %%
k1= sns.kdeplot(data=movie, x= 'Budget',y='AudienceRatings',shade_lowest=False, cmap='Greens_r')

# %%
k1= sns.kdeplot(data=movie, x='Budget', y = 'AudienceRatings')

# %%
#subplot

# %%
f,ax = plt.subplots(1,2,figsize=(12,6))

# %%
f,ax=plt.subplots(3,3,figsize=(12,6))

# %%
f, axes = plt.subplots(1,2,figsize=(12,6))
k1= sns.kdeplot(data=movie, x='Budget',y='AudienceRatings',ax=axes[0])
k2=sns.kdeplot(data=movie, x='Budget',y='CriticRating', ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='Budget', ylabel='AudienceRatings'>,
#        <Axes: xlabel='Budget', ylabel='CriticRating'>], dtype=object)

# %%
#boxplot
w = sns.boxplot(data=movie,x='Genre',y='CriticRating')

# %%
#violin plot
z=sns.violinplot(data=movie, x='Genre',y='CriticRating')

# %%
w1= sns.boxplot(data=movie[movie.Genre=='Drama'],x='Year',y='CriticRating')

# %%
z= sns.violinplot(data=movie[movie.Genre=='Drama'],x='Year',y='CriticRating')

# %%
#creating a facegrid
plt.style.use('default')
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre' )

# %%
plt.style.use('dark_background')
plt.scatter(movie.CriticRating,movie.AudienceRatings)

# %%
plt.style.use('dark_background')
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
g= g.map(plt.scatter,'CriticRating','AudienceRatings')
# scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat.
g= sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
g= g.map(plt.hist,'Budget') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (8,8))

k1 = sns.kdeplot(x = movie.Budget,y = movie.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(x = movie.Budget,y = movie.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x = movie.CriticRating,y=movie.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x = movie.CriticRating,y = movie.AudienceRatings,cmap='Reds',ax = axes[1,1])

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x = movie.Budget,y = movie.AudienceRatings, \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x= movie.Budget,y =  movie.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x= movie.Budget,y=movie.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=movie.Budget,y=movie.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movie[movie.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x = movie.CriticRating,y =movie.AudienceRatings, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(x = movie.CriticRating,y = movie.AudienceRatings, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20.0, 160.0)]

# %% [markdown]
# Final discussion what we learn so far -
# 1> category datatype in python
# 2> jointplots
# 3> histogram
# 4> stacked histograms
# 5> Kde plot
# 6> subplot
# 7> violin plots
# 8> Factet grid
# 9> Building dashboards
