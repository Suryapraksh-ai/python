# %%
import openpyxl

# %%
import pandas as pd

# %%
workbook = openpyxl.Workbook()

# %%
sheet = workbook.active

# %%
data = [
    ['NAME','DOMAIN','AGE','LOCATION','SALERY','EXP'],
        ['ALEX','TESTING',25,'BNG',5000,2],
        ['CHERRY','TESTING',30,'BNG',10000,3],
        ['KYTHI','TESTING',35,'BNG',15000,4],
        ['ALEX','TESTING',38,'BNG',15000,5],
        ['ALEX','TESTING',40,'BNG',50000,6]
]
for row in data:
   sheet.append(row)

workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALERY', 'EXP'],
#  ['ALEX', 'TESTING', 25, 'BNG', 5000, 2],
#  ['CHERRY', 'TESTING', 30, 'BNG', 10000, 3],
#  ['KYTHI', 'TESTING', 35, 'BNG', 15000, 4],
#  ['ALEX', 'TESTING', 38, 'BNG', 15000, 5],
#  ['ALEX', 'TESTING', 40, 'BNG', 50000, 6]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ICON'

# %%
emp = pd.read_excel(r'C:\\Users\\ICON\data.xlsx')

# %% [markdown]
# emp

# %%
emp
# Out:
#      NAME   DOMAIN  AGE LOCATION  SALERY  EXP
# 0    ALEX  TESTING   25      BNG    5000    2
# 1  CHERRY  TESTING   30      BNG   10000    3
# 2   KYTHI  TESTING   35      BNG   15000    4
# 3    ALEX  TESTING   38      BNG   15000    5
# 4    ALEX  TESTING   40      BNG   50000    6

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visl = sns.displot(emp['SALERY'])

# %%
plt.rcParams['figure.figsize'] = 5,1

# %%
vis5 = sns.lmplot(data=emp, x = 'EXP', y = 'SALERY')

# %%
visl = sns.distplot(emp['SALERY'])
# Out:
# C:\Users\ICON\AppData\Local\Temp\ipykernel_13780\1123761238.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   visl = sns.distplot(emp['SALERY'])

# %%
vis3 = plt.hist(emp['SALERY'])

# %%
vis5=sns.lmplot(data = emp, x = 'EXP', y = 'SALERY', fit_reg = False)

# %%
vis6 = sns.lmplot(data = emp, x = 'EXP', y = 'SALERY', fit_reg = True)
